# %%
import pandas as pd
import importlib

import utilities
importlib.reload(utilities)
# Out:
# <module 'utilities' from '/home/ano/Projekty/FASTROLL/utilities.py'>

# %%
kaggle_df = pd.read_csv('datasets/kaggle.csv')
kaggle_df
# Out:
#                                                       epd  Winner
# 0       rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR ...       1
# 1       rnbqkbnr/ppp1pppp/8/3p4/3P4/8/PPP1PPPP/RNBQKBN...       1
# 2       rnbqkbnr/ppp1pppp/8/3p4/2PP4/8/PP2PPPP/RNBQKBN...       1
# 3       rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/8/PP2PPPP/RNBQKB...       1
# 4       rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/2N5/PP2PPPP/R1BQ...       1
# ...                                                   ...     ...
# 100086            6R1/8/4P3/2pB2b1/P1P3k1/3r4/8/4K3 b - -       1
# 100087            6R1/8/4P3/2pB2b1/P1P2k2/3r4/8/4K3 w - -       1
# 100088              8/8/4P3/2pB2R1/P1P2k2/3r4/8/4K3 b - -       1
# 100089                8/8/4P3/2pB2k1/P1P5/3r4/8/4K3 w - -       1
# 100090                8/8/4P3/2pB2k1/P1P5/3r4/4K3/8 b - -       1
#
# [100091 rows x 2 columns]

# %%
rollouts_df = pd.read_csv('datasets/rollouts.csv')
rollouts_df
# Out:
#                                                      FEN  Winner
# 0      rnbqkbnr/pppppppp/8/8/8/5P2/PPPPP1PP/RNBQKBNR ...       0
# 1      rnbqkbnr/pp1ppppp/8/2p5/8/5P2/PPPPP1PP/RNBQKBN...       0
# 2      rnbqkbnr/pp1ppppp/8/2p5/8/5P1N/PPPPP1PP/RNBQKB...       0
# 3      rnbqkbnr/pp1p1ppp/4p3/2p5/8/5P1N/PPPPP1PP/RNBQ...       0
# 4      rnbqkbnr/pp1p1ppp/4p3/2p5/3P4/5P1N/PPP1P1PP/RN...       0
# ...                                                  ...     ...
# 99995  rn3knr/p1q3pp/1p1p1p2/1bpBQ3/1b2P2R/2P2K2/PB1P...       0
# 99996  rn3knr/p3q1pp/1p1p1p2/1bpBQ3/1b2P2R/2P2K2/PB1P...       1
# 99997  rn3knr/p3q1pp/1p1p1p2/1bpBQ3/1b2P3/2P2K2/PB1P1...       0
# 99998  rn3knr/p2q2pp/1p1p1p2/1bpBQ3/1b2P3/2P2K2/PB1P1...       1
# 99999  rn3knr/p2q2pp/1p1p1p2/1bpBQ3/1b2P3/2P2K2/PB1P1...       0
#
# [100000 rows x 2 columns]

# %%
random_df = pd.read_csv('datasets/random.csv')
rollouts_df
# Out:
#                                                      FEN  Winner
# 0      rnbqkbnr/pppppppp/8/8/8/5P2/PPPPP1PP/RNBQKBNR ...       0
# 1      rnbqkbnr/pp1ppppp/8/2p5/8/5P2/PPPPP1PP/RNBQKBN...       0
# 2      rnbqkbnr/pp1ppppp/8/2p5/8/5P1N/PPPPP1PP/RNBQKB...       0
# 3      rnbqkbnr/pp1p1ppp/4p3/2p5/8/5P1N/PPPPP1PP/RNBQ...       0
# 4      rnbqkbnr/pp1p1ppp/4p3/2p5/3P4/5P1N/PPP1P1PP/RN...       0
# ...                                                  ...     ...
# 99995  rn3knr/p1q3pp/1p1p1p2/1bpBQ3/1b2P2R/2P2K2/PB1P...       0
# 99996  rn3knr/p3q1pp/1p1p1p2/1bpBQ3/1b2P2R/2P2K2/PB1P...       1
# 99997  rn3knr/p3q1pp/1p1p1p2/1bpBQ3/1b2P3/2P2K2/PB1P1...       0
# 99998  rn3knr/p2q2pp/1p1p1p2/1bpBQ3/1b2P3/2P2K2/PB1P1...       1
# 99999  rn3knr/p2q2pp/1p1p1p2/1bpBQ3/1b2P3/2P2K2/PB1P1...       0
#
# [100000 rows x 2 columns]

# %% [markdown]
# # Kaggle data set pieces distribution

# %%
utilities.draw_histograms(kaggle_df)
# Out:
# ...
# 100%|██████████| 100091/100091 [00:09<00:00, 11067.45it/s]

# %% [markdown]
# # Rollouts data set pieces distribution

# %%
utilities.draw_histograms(rollouts_df)
# Out:
# ...
# 100%|██████████| 100000/100000 [00:06<00:00, 14341.22it/s]

# %%
utilities.draw_histograms(random_df)
# Out:
# ...
#   0%|          | 0/100000 [00:00<?, ?it/s]
